# %%
import pandas as pd
import json
import os
from tqdm import tqdm
import spacy
from spacy.tokens import DocBin

# %% [markdown]
# # For training data

# %% [markdown]
# ### Updating the json annotaion file
#
# Making changes to the JSON annotation file as per spacy requirements

# %%
with open(r'D:\MACHINE LEARNING\Meeting Analysis\Data\annotations.json', 'r') as f:
    data = json.load(f)

# %%
data
# Out:
# {'classes': ['TEXT', 'ASSIGNEE'],
#  'annotations': [['I have an important task that needs to be assigned to someone. It involves analyzing the market trends and preparing a report.\r',
#    {'entities': [[75, 125, 'TEXT']]}],
#   ['We need someone to take charge of the project management tasks for the upcoming product launch. Any volunteers?\r',
#    {'entities': [[38, 56, 'TEXT']]}],
#   ['I would like to assign the task of conducting user research and gathering feedback to John. Are you available, John?\r',
#    {'entities': [[46, 82, 'TEXT']]}],
#   ["As discussed earlier, we need to assign the coding tasks for the new feature implementation. Let's distribute them among the development team.\r",
#    {'entities': [[44, 92, 'TEXT']]}],
#   ['We have an urgent task of organizing the client meeting next week. Can someone from the sales team take care of it?\r',
#    {'entities': [[26, 55, 'TEXT']]}],
#   ["We have a task to prepare a detailed project plan. Let's assign this task to someone from the project management team.\r",
#    {'entities': [[18, 50, 'TEXT']]}],
#   ['We need to assign someone to conduct market research and gather insights for our upcoming product launch.\r',
#    {'entities': [[29, 104, 'TEXT']]}],
#   ['I propose we assign the task of creating a presentation for the client meeting to one of our design experts.\r',
#    {'entities': [[32, 78, 'TEXT']]}],
#   ['We have a task to review and finalize the budget for the next fiscal year. Who can take charge of this task?\r',
#    {'entities': [[18, 74, 'TEXT']]}],
#   ["Let's assign the task of coordinating logistics and travel arrangements for the upcoming conference to our admin team.\r",
#    {'entities': [[25, 71, 'TEXT']]}],
#   ['We need someone to lead the customer feedback analysis task and provide actionable insights to improve our product.\r',
#    {'entities': [[19, 114, 'TEXT']]}],
#   ["It's crucial that we assign someone to conduct user testing and gather feedback on the new app interface.\r",
#    {'entities': [[39, 104, 'TEXT']]}],
#   ['We have a task to research and recommend potential vendors for our upcoming software development project.\r',
#    {'entities': [[18, 58, 'TEXT']]}],
#   ["Let's assign the task of drafting the project proposal to someone with strong writing and research skills.\r",
#    {'entities': [[25, 54, 'TEXT']]}],
#   ['We need to assign someone to coordinate with the sales team and gather requirements for the new CRM system.\r',
#    {'entities': [[29, 106, 'TEXT']]}],
#   ['We should assign someone to conduct market research and identify potential competitors in the industry.\r',
#    {'entities': [[28, 102, 'TEXT']]}],
#   ["Let's assign the task of preparing the financial projections for the next quarter to someone with expertise in financial analysis.\r",
#    {'entities': [[25, 81, 'TEXT']]}],
#   ['We need to assign someone to coordinate with the design team and create a mockup for the new website layout.\r',
#    {'entities': [[29, 107, 'TEXT']]}],
#   ["It's important that we assign someone to lead the project management task and ensure timely delivery of milestones.\r",
#    {'entities': [[41, 73, 'TEXT']]}],
#   ["We should assign someone to handle the logistics and coordinate the team's travel arrangements for the upcoming conference.\r",
#    {'entities': [[28, 94, 'TEXT']]}],
#   ["Let's assign someone to conduct user testing and gather feedback on the new mobile app interface.\r",
#    {'entities': [[24, 96, 'TEXT']]}],
#   ['We need to assign someone to write the project proposal and include the timeline and deliverables.\r',
#    {'entities': [[29, 97, 'TEXT']]}],
#   ['It would be great if someone can take on the task of creating the presentation slides for the client pitch.\r',
#    {'entities': [[53, 106, 'TEXT']]}],
#   ['We should assign someone to review the customer feedback and identify areas for product improvement.\r',
#    {'entities': [[28, 99, 'TEXT']]}],
#   ["Let's assign someone to coordinate with the legal team and draft the contract for the new partnership.\r",
#    {'entities': [[24, 101, 'TEXT']]}],
#   ['We need to assign someone to lead the recruitment process and screen potential candidates for the open positions.\r',
#    {'entities': [[29, 112, 'TEXT']]}],
#   ["It's crucial that we assign someone to handle the budgeting and financial forecasting for the project.\r",
#    {'entities': [[39, 101, 'TEXT']]}],
#   ['We should assign someone to analyze market trends and competitor strategies to inform our marketing strategy.\r',
#    {'entities': [[28, 108, 'TEXT']]}],
#   ["Let's assign someone to conduct a risk assessment and develop a mitigation plan for the project.\r",
#    {'entities': [[24, 95, 'TEXT']]}],
#   ['We need to assign someone to coordinate with the IT department and ensure smooth implementation of the new software.\r',
#    {'entities': [[29, 115, 'TEXT']]}],
#   ['We should assign someone to conduct a market research analysis and identify potential target demographics.\r',
#    {'entities': [[28, 105, 'TEXT']]}],
#   ["Let's assign someone to schedule and coordinate meetings with key stakeholders for the upcoming project.\r",
#    {'entities': [[24, 78, 'TEXT']]}],
#   ['We need to assign someone to review and update the project documentation to reflect the latest changes.\r',
#    {'entities': [[29, 102, 'TEXT']]}],
#   ['It would be great if someone can take on the task of preparing the agenda for the next team meeting.\r',
#    {'entities': [[53, 73, 'TEXT']]}],
#   ['We should assign someone to conduct a competitive analysis and benchmark our product against industry leaders.\r',
#    {'entities': [[28, 109, 'TEXT']]}],
#   ["Let's assign someone to lead the user experience design and ensure a seamless interface for our customers.\r",
#    {'entities': [[24, 105, 'TEXT']]}],
#   ['We need to assign someone to manage the social media accounts and create engaging content for our followers.\r',
#    {'entities': [[29, 107, 'TEXT']]}],
#   ["It's crucial that we assign someone to coordinate the logistics and travel arrangements for the upcoming conference.\r",
#    {'entities': [[39, 87, 'TEXT']]}],
#   ['We should assign someone to monitor and analyze key performance indicators to track the success of our marketing campaigns.\r',
#    {'entities': [[28, 122, 'TEXT']]}],
#   ["Let's assign someone to conduct a usability test and gather feedback on the new website design.\r",
#    {'entities': [[24, 94, 'TEXT']]}],
#   ['Schedule and coordinate meetings with key stakeholders for the upcoming project.\r',
#    {'entities': [[0, 54, 'TEXT']]}],
#   ['Review and update project documentation to reflect the latest changes.\r',
#    {'entities': [[0, 69, 'TEXT']]}],
#   ['Prepare the agenda for the next team meeting.\r',
#    {'entities': [[0, 18, 'TEXT']]}],
#   ['Conduct a competitive analysis and benchmark our product against industry leaders.\r',
#    {'entities': [[10, 81, 'TEXT']]}],
#   ['Lead the user experience design and ensure a seamless interface.\r',
#    {'entities': [[0, 63, 'TEXT']]}],
#   ['Manage social media accounts and create engaging content for followers.\r',
#    {'entities': [[0, 70, 'TEXT']]}],
#   ['Coordinate logistics and travel arrangements for the upcoming conference.\r',
#    {'entities': [[0, 44, 'TEXT']]}],
#   ['Monitor and analyze key performance indicators for marketing campaigns.\r',
#    {'entities': [[0, 70, 'TEXT']]}],
#   ['Conduct a usability test and gather feedback on the new website design.\r',
#    {'entities': [[10, 70, 'TEXT']]}],
#   ['Develop a project timeline and assign milestones to team members.\r',
#    {'entities': [[0, 64, 'TEXT']]}],
#   ['Task assigned: Research and propose new software tools for process automation.\r',
#    {'entities': [[15, 78, 'TEXT']]}],
#   ['Create a detailed project budget and allocate resources accordingly.\r',
#    {'entities': [[9, 67, 'TEXT']]}],
#   ["Conduct training sessions to enhance team members' technical skills.\r",
#    {'entities': [[8, 67, 'TEXT']]}],
#   ['Draft a comprehensive project proposal outlining objectives and deliverables.\r',
#    {'entities': [[0, 76, 'TEXT']]}],
#   ['Implement a data backup and recovery plan to ensure data security.\r',
#    {'entities': [[0, 65, 'TEXT']]}],
#   ['Develop a customer satisfaction survey and analyze the results.\r',
#    {'entities': [[0, 62, 'TEXT']]}],
#   ['Task assigned: Create a content calendar for social media posts and schedule content.\r',
#    {'entities': [[15, 76, 'TEXT']]}],
#   ['Conduct interviews to hire additional team members for project support.\r',
#    {'entities': [[8, 70, 'TEXT']]}],
#   ['Establish a communication plan to ensure effective team collaboration.\r',
#    {'entities': [[0, 69, 'TEXT']]}],
#   ['Identify potential target demographics.\r',
#    {'entities': [[0, 38, 'TEXT']]}],
#   ['Could you please prepare a project timeline and deliverables for client review?\r',
#    {'entities': []}],
#   ["We need your expertise to conduct a competitive analysis and present your findings in next week's meeting.\r",
#    {'entities': [[26, 82, 'TEXT']]}],
#   ['It would be great if you could research and propose new marketing strategies to attract our target audience.\r',
#    {'entities': [[31, 107, 'TEXT']]}],
#   ['Your task is to update the website content and ensure it aligns with the latest brand guidelines.\r',
#    {'entities': [[16, 96, 'TEXT']]}],
#   ['Can you coordinate with the sales team to finalize pricing for the upcoming product launch?\r',
#    {'entities': [[8, 90, 'TEXT']]}],
#   ['We would like you to create a comprehensive project plan with clear milestones and deadlines.\r',
#    {'entities': [[21, 56, 'TEXT']]}],
#   ['Could you please conduct market research to identify potential expansion opportunities in new regions?\r',
#    {'entities': [[17, 101, 'TEXT']]}],
#   ['Your action item is to develop a customer retention strategy and present it to the leadership team.\r',
#    {'entities': [[23, 98, 'TEXT']]}],
#   ['It would be great if you could analyze customer feedback data and identify areas for product improvement.\r',
#    {'entities': [[31, 104, 'TEXT']]}],
#   ['Can you prepare a detailed budget proposal for the upcoming marketing campaign?\r',
#    {'entities': [[8, 78, 'TEXT']]}],
#   ['Your task is to coordinate logistics and ensure a smooth execution of the upcoming company event.\r',
#    {'entities': [[16, 96, 'TEXT']]}],
#   ['We need your expertise to research and recommend new software tools to streamline our internal processes.\r',
#    {'entities': [[26, 104, 'TEXT']]}],
#   ['It would be great if you could conduct user testing sessions to gather feedback on the latest product prototype.\r',
#    {'entities': [[31, 79, 'TEXT']]}],
#   ['Can you develop a content marketing strategy to increase our brand visibility and engagement?\r',
#    {'entities': [[18, 92, 'TEXT']]}],
#   ['Your task is to implement a data tracking system to monitor key performance indicators.\r',
#    {'entities': [[28, 86, 'TEXT']]}],
#   ['Could you please create a comprehensive training program for new hires to ensure a smooth onboarding process?\r',
#    {'entities': [[17, 108, 'TEXT']]}],
#   ['We need your expertise to establish key performance metrics and benchmarks for the sales team.\r',
#    {'entities': [[26, 93, 'TEXT']]}],
#   ['Your task is to develop a social media content calendar for the next quarter.\r',
#    {'entities': [[26, 76, 'TEXT']]}],
#   ['It would be great if you could conduct interviews to identify and hire a qualified candidate for the vacant position.\r',
#    {'entities': [[39, 116, 'TEXT']]}],
#   ['Can you conduct a SWOT analysis to identify our strengths, weaknesses, opportunities, and threats?\r',
#    {'entities': [[18, 97, 'TEXT']]}],
#   ['Could you please perform data analysis to identify key trends and insights for our upcoming report?\r',
#    {'entities': [[25, 98, 'TEXT']]}],
#   ['We need you to create a detailed project timeline and allocate resources accordingly.\r',
#    {'entities': [[24, 84, 'TEXT']]}],
#   ['It would be great if you could develop a marketing strategy to promote our new product launch.\r',
#    {'entities': [[31, 93, 'TEXT']]}],
#   ['Your task is to draft a proposal outlining potential cost-saving measures for the department.\r',
#    {'entities': [[24, 92, 'TEXT']]}],
#   ['Can you coordinate with the design team to create visually appealing graphics for our upcoming presentation?\r',
#    {'entities': [[28, 107, 'TEXT']]}],
#   ['We would like you to conduct market research and prepare a competitive analysis report.\r',
#    {'entities': [[29, 86, 'TEXT']]}],
#   ['Could you please review the current processes and suggest areas for optimization?\r',
#    {'entities': [[17, 80, 'TEXT']]}],
#   ['Your action item is to create a customer survey and gather feedback on our latest product release.\r',
#    {'entities': [[32, 97, 'TEXT']]}],
#   ['It would be great if you could develop a training program for new employees to ensure a smooth onboarding process.\r',
#    {'entities': [[31, 113, 'TEXT']]}],
#   ['Can you coordinate with the IT department to resolve technical issues related to the software upgrade?\r',
#    {'entities': [[8, 101, 'TEXT']]}],
#   ['Your task is to prepare a presentation summarizing the key findings from the recent market research study.\r',
#    {'entities': [[16, 105, 'TEXT']]}],
#   ['We need you to analyze financial data and provide recommendations for cost reduction.\r',
#    {'entities': [[15, 84, 'TEXT']]}],
#   ['It would be great if you could coordinate logistics for the upcoming team offsite event.\r',
#    {'entities': [[31, 87, 'TEXT']]}],
#   ['Can you review the current social media strategy and propose improvements to increase engagement?\r',
#    {'entities': [[8, 96, 'TEXT']]}],
#   ['Your task is to conduct user testing sessions to gather feedback on the new website design.\r',
#    {'entities': [[16, 90, 'TEXT']]}],
#   ['Could you please prepare a detailed project plan for the upcoming product launch?\r',
#    {'entities': [[17, 80, 'TEXT']]}],
#   ['We need your expertise to develop a content calendar for the company blog.\r',
#    {'entities': [[26, 73, 'TEXT']]}],
#   ['Your task is to conduct interviews and assist in the hiring process for a new team member.\r',
#    {'entities': [[24, 89, 'TEXT']]}],
#   ['It would be great if you could research and recommend software solutions to improve productivity.\r',
#    {'entities': [[31, 96, 'TEXT']]}],
#   ['Can you conduct a customer satisfaction survey and analyze the results for actionable insights?\r',
#    {'entities': [[18, 94, 'TEXT']]}],
#   ['Mohit, conduct a customer satisfaction survey and analyze the results for actionable insights.\r',
#    {'entities': [[17, 93, 'TEXT']]}],
#   ['Sophie, create a detailed project timeline and allocate resources accordingly.\r',
#    {'entities': [[17, 77, 'TEXT']]}],
#   ['Emily, develop a marketing strategy to promote our new product launch.\r',
#    {'entities': [[17, 69, 'TEXT']]}],
#   ['Jacob, draft a proposal outlining potential cost-saving measures for the department.\r',
#    {'entities': [[15, 83, 'TEXT']]}],
#   ['Oliver, coordinate with the design team to create visually appealing graphics for our upcoming presentation.\r',
#    {'entities': [[8, 107, 'TEXT']]}],
#   ['Emma, conduct market research and prepare a competitive analysis report.\r',
#    {'entities': [[6, 71, 'TEXT']]}],
#   ['Noah, review the current processes and suggest areas for optimization.\r',
#    {'entities': [[6, 69, 'TEXT']]}],
#   ['Ava, create a customer survey and gather feedback on our latest product release.\r',
#    {'entities': [[0, 3, 'ASSIGNEE'], [14, 79, 'TEXT']]}],
#   ['William, develop a training program for new employees to ensure a smooth onboarding process.\r',
#    {'entities': [[0, 7, 'ASSIGNEE'], [9, 91, 'TEXT']]}],
#   ['Liam, coordinate with the IT department to resolve technical issues related to the software upgrade.\r',
#    {'entities': [[0, 4, 'ASSIGNEE'], [6, 99, 'TEXT']]}],
#   ['Ella, prepare a presentation summarizing the key findings from the recent market research study.\r',
#    {'entities': [[0, 4, 'ASSIGNEE'], [6, 95, 'TEXT']]}],
#   ['Sophia, analyze financial data and provide recommendations for cost reduction.\r',
#    {'entities': [[0, 6, 'ASSIGNEE'], [8, 77, 'TEXT']]}],
#   ['Michael, coordinate logistics for the upcoming team offsite event.\r',
#    {'entities': [[0, 7, 'ASSIGNEE'], [9, 65, 'TEXT']]}],
#   ['Grace, review the current social media strategy and propose improvements to increase engagement.\r',
#    {'entities': []}],
#   ['Daniel, conduct usability testing for the new website design.\r',
#    {'entities': [[0, 6, 'ASSIGNEE'], [8, 60, 'TEXT']]}],
#   ['Ethan, research and identify potential partnership opportunities with industry influencers.\r',
#    {'entities': [[0, 5, 'ASSIGNEE'], [7, 90, 'TEXT']]}],
#   ['Mia, draft a press release announcing our latest product launch.\r',
#    {'entities': [[0, 3, 'ASSIGNEE'], [5, 63, 'TEXT']]}],
#   ['Olivia, compile and analyze customer feedback to identify common pain points.\r',
#    {'entities': [[0, 6, 'ASSIGNEE'], [8, 76, 'TEXT']]}],
#   ['Logan, collaborate with the sales team to develop a new pricing strategy.\r',
#    {'entities': [[0, 5, 'ASSIGNEE'], [7, 72, 'TEXT']]}],
#   ['Chloe, create a comprehensive training manual for new employees.\r',
#    {'entities': [[0, 5, 'ASSIGNEE'], [7, 63, 'TEXT']]}],
#   ['Emily, coordinate with the design team to create a visually appealing user interface.\r',
#    {'entities': [[0, 5, 'ASSIGNEE'], [7, 84, 'TEXT']]}],
#   ["Owen, conduct a competitive analysis of our main competitors' marketing campaigns.\r",
#    {'entities': [[0, 4, 'ASSIGNEE'], [6, 81, 'ASSIGNEE']]}],
#   ['Zoe, organize and lead a brainstorming session\r',
#    {'entities': [[0, 3, 'ASSIGNEE'], [5, 46, 'TEXT']]}],
#   ['Nathan, prepare a comprehensive sales report for the quarter.\r',
#    {'entities': [[0, 6, 'ASSIGNEE'], [8, 60, 'TEXT']]}],
#   ["Sophie, conduct a thorough analysis of our website's user experience and suggest improvements.\r",
#    {'entities': [[0, 6, 'ASSIGNEE'], [8, 93, 'TEXT']]}],
#   ['Emily, create a detailed project plan outlining milestones and deliverables.\r',
#    {'entities': [[0, 5, 'ASSIGNEE'], [7, 75, 'TEXT']]}],
#   ['Jacob, research and recommend a customer relationship management (CRM) software for the team.\r',
#    {'entities': [[0, 5, 'ASSIGNEE'], [7, 92, 'TEXT']]}],
#   ['Oliver, prepare a presentation on the latest market trends and their impact on our industry.\r',
#    {'entities': [[0, 6, 'ASSIGNEE'], [8, 91, 'TEXT']]}],
#   ['Emma, coordinate with the content team to develop engaging blog posts for our target audience.\r',
#    {'entities': [[0, 4, 'ASSIGNEE'], [6, 93, 'TEXT']]}],
#   ['Noah, analyze the data from our recent advertising campaign and provide insights on its effectiveness.\r',
#    {'entities': [[0, 4, 'ASSIGNEE'], [6, 101, 'TEXT']]}],
#   ['Ava, conduct a competitor analysis and identify potential opportunities for product differentiation.\r',
#    {'entities': [[0, 3, 'ASSIGNEE'], [5, 99, 'TEXT']]}],
#   ['William, create a training manual for our new customer service representatives.\r',
#    {'entities': [[0, 7, 'ASSIGNEE'], [9, 78, 'TEXT']]}],
#   ['Liam, develop a social media content calendar for the upcoming month.\r',
#    {'entities': [[0, 4, 'ASSIGNEE'], [6, 68, 'TEXT']]}],
#   ['Ella, review and optimize our email marketing campaigns to increase open and click-through rates.\r',
#    {'entities': [[0, 4, 'ASSIGNEE'], [6, 96, 'TEXT']]}],
#   ['Sophia, coordinate with the HR department to streamline our recruitment process.\r',
#    {'entities': [[0, 6, 'ASSIGNEE'], [8, 79, 'TEXT']]}],
#   ['Michael, conduct a cost analysis of our manufacturing processes and propose cost-saving measures.\r',
#    {'entities': [[0, 7, 'ASSIGNEE'], [9, 96, 'TEXT']]}],
#   ['Grace, organize a team-building event to enhance collaboration and morale within the team.\r',
#    {'entities': [[0, 5, 'ASSIGNEE'], [7, 89, 'TEXT']]}],
#   ['Daniel, conduct a market research survey to gather insights on customer preferences and expectations.\r',
#    {'entities': [[0, 6, 'ASSIGNEE'], [8, 100, 'TEXT']]}],
#   ['Ethan, develop a comprehensive onboarding program for new hires.\r',
#    {'entities': [[0, 5, 'ASSIGNEE'], [7, 63, 'TEXT']]}],
#   ['Mia, create a visually appealing presentation template for future client meetings.\r',
#    {'entities': [[0, 3, 'ASSIGNEE'], [5, 81, 'TEXT']]}],
#   ['Olivia, analyze website traffic data and propose strategies to increase conversion rates.\r',
#    {'entities': [[0, 6, 'ASSIGNEE'], [8, 88, 'TEXT']]}],
#   ['Logan, collaborate with the finance team to develop a budget for an upcoming project.\r',
#    {'entities': [[0, 5, 'ASSIGNEE'], [7, 84, 'TEXT']]}],
#   ['Chloe, conduct a product demo for potential clients and gather feedback for product improvement.\r',
#    {'entities': [[0, 5, 'ASSIGNEE'], [7, 95, 'TEXT']]}],
#   ['Emily, coordinate with the design team to create a visually appealing user interface for the new software.\r',
#    {'entities': [[0, 5, 'ASSIGNEE'], [7, 105, 'TEXT']]}],
#   ['Owen, research and propose a new vendor for our office supplies to reduce\r',
#    {'entities': [[0, 4, 'ASSIGNEE'], [6, 73, 'TEXT']]}],
#   ['Nathan, conduct a thorough analysis of our customer feedback and suggest improvements for our products.\r',
#    {'entities': [[0, 6, 'ASSIGNEE'], [8, 102, 'TEXT']]}],
#   ['Sophie, create a marketing campaign targeting our new customer segment.\r',
#    {'entities': [[0, 6, 'ASSIGNEE'], [8, 70, 'TEXT']]}],
#   ['Emily, prepare a presentation on the latest industry trends and their impact on our business.\r',
#    {'entities': [[0, 5, 'ASSIGNEE'], [7, 92, 'TEXT']]}],
#   ['Jacob, research and recommend a project management tool for better team collaboration.\r',
#    {'entities': [[0, 5, 'ASSIGNEE'], [7, 85, 'TEXT']]}],
#   ['Oliver, develop a training program for our sales team to enhance their negotiation skills.\r',
#    {'entities': [[0, 6, 'ASSIGNEE'], [8, 89, 'TEXT']]}],
#   ['Emma, coordinate with the IT department to implement a new data analytics system.\r',
#    {'entities': [[0, 4, 'ASSIGNEE'], [6, 80, 'TEXT']]}],
#   ['Noah, analyze customer feedback and propose improvements to our product packaging.\r',
#    {'entities': [[0, 4, 'ASSIGNEE'], [6, 81, 'TEXT']]}],
#   ['Ava, conduct market research to identify potential new target markets for our services.\r',
#    {'entities': [[0, 3, 'ASSIGNEE'], [5, 86, 'TEXT']]}],
#   ['William, prepare a cost-benefit analysis for investing in new equipment for the production line.\r',
#    {'entities': [[0, 7, 'ASSIGNEE'], [9, 95, 'TEXT']]}],
#   ['Liam, develop a social media advertising campaign to increase brand awareness.\r',
#    {'entities': [[0, 4, 'ASSIGNEE'], [6, 77, 'TEXT']]}],
#   ["Ella, review and update our company's privacy policy to comply with new regulations.\r",
#    {'entities': [[0, 4, 'ASSIGNEE'], [6, 83, 'TEXT']]}],
#   ['Sophia, coordinate with the HR department to design a comprehensive employee wellness program.\r',
#    {'entities': [[0, 6, 'ASSIGNEE'], [8, 93, 'TEXT']]}],
#   ['Michael, conduct a market analysis to identify potential business expansion opportunities.\r',
#    {'entities': [[0, 7, 'ASSIGNEE'], [9, 89, 'TEXT']]}],
#   ['Grace, create a customer loyalty program to increase customer retention rates.\r',
#    {'entities': [[0, 5, 'ASSIGNEE'], [7, 77, 'TEXT']]}],
#   ['Daniel, develop a content marketing strategy to attract and engage our target audience.\r',
#    {'entities': [[0, 6, 'ASSIGNEE'], [8, 86, 'TEXT']]}],
#   ['Ethan, research and recommend a customer support software for better customer service management.\r',
#    {'entities': [[0, 5, 'ASSIGNEE'], [7, 96, 'TEXT']]}],
#   ['Mia, collaborate with the design team to create a new company logo and brand identity.\r',
#    {'entities': [[0, 3, 'ASSIGNEE'], [5, 85, 'TEXT']]}],
#   ['Olivia, analyze sales data and propose strategies to increase revenue and profitability.\r',
#    {'entities': [[0, 6, 'ASSIGNEE'], [8, 87, 'TEXT']]}],
#   ['Logan, develop a project plan for launching a new product in the market.\r',
#    {'entities': [[0, 5, 'ASSIGNEE'], [7, 71, 'TEXT']]}],
#   ['Chloe, conduct a competitor analysis and provide recommendations for product differentiation.\r',
#    {'entities': [[0, 5, 'ASSIGNEE'], [7, 93, 'TEXT']]}],
#   ['Aria, review the current customer onboarding process and suggest improvements.\r',
#    {'entities': [[0, 4, 'ASSIGNEE'], [6, 77, 'TEXT']]}],
#   ['Harper, conduct a usability testing session for our website and identify areas for improvement.\r',
#    {'entities': [[0, 6, 'ASSIGNEE'], [8, 94, 'TEXT']]}],
#   ['Nathan, conduct a thorough analysis of our customer feedback and suggest improvements for our products.\r',
#    {'entities': [[0, 6, 'ASSIGNEE'], [8, 102, 'TEXT']]}],
#   ['Sophie, create a marketing campaign targeting our new customer segment.\r',
#    {'entities': [[0, 6, 'ASSIGNEE'], [8, 70, 'TEXT']]}],
#   ['Emily, prepare a presentation on the latest industry trends and their impact on our business.\r',
#    {'entities': [[0, 5, 'ASSIGNEE'], [7, 92, 'TEXT']]}],
#   ['Jacob, research and recommend a project management tool for better team collaboration.\r',
#    {'entities': [[0, 5, 'ASSIGNEE'], [7, 85, 'TEXT']]}],
#   ['Oliver, develop a training program for our sales team to enhance their negotiation skills.\r',
#    {'entities': [[0, 6, 'ASSIGNEE'], [8, 89, 'TEXT']]}],
#   ['Emma, coordinate with the IT department to implement a new data analytics system.\r',
#    {'entities': [[0, 4, 'ASSIGNEE'], [6, 80, 'TEXT']]}],
#   ['Noah, analyze customer feedback and propose improvements to our product packaging.\r',
#    {'entities': [[0, 4, 'ASSIGNEE'], [6, 81, 'TEXT']]}],
#   ['Ava, conduct market research to identify potential new target markets for our services.\r',
#    {'entities': [[0, 3, 'ASSIGNEE'], [5, 86, 'TEXT']]}],
#   ['William, prepare a cost-benefit analysis for investing in new equipment for the production line.\r',
#    {'entities': [[0, 7, 'ASSIGNEE'], [9, 95, 'TEXT']]}],
#   ['Liam, develop a social media advertising campaign to increase brand awareness.\r',
#    {'entities': [[0, 4, 'ASSIGNEE'], [6, 77, 'TEXT']]}],
#   ["Ella, review and update our company's privacy policy to comply with new regulations.\r",
#    {'entities': [[0, 4, 'ASSIGNEE'], [6, 83, 'TEXT']]}],
#   ['Sophia, coordinate with the HR department to design a comprehensive employee wellness program.\r',
#    {'entities': [[0, 6, 'ASSIGNEE'], [8, 93, 'TEXT']]}],
#   ['Michael, conduct a market analysis to identify potential business expansion opportunities.\r',
#    {'entities': [[0, 7, 'ASSIGNEE'], [9, 89, 'TEXT']]}],
#   ['Grace, create a customer loyalty program to increase customer retention rates.\r',
#    {'entities': [[0, 5, 'ASSIGNEE'], [7, 77, 'TEXT']]}],
#   ['Daniel, develop a content marketing strategy to attract and engage our target audience.\r',
#    {'entities': [[0, 6, 'ASSIGNEE'], [8, 86, 'TEXT']]}],
#   ['Ethan, research and recommend a customer support software for better customer service management.\r',
#    {'entities': [[0, 5, 'ASSIGNEE'], [7, 96, 'TEXT']]}],
#   ['Mia, collaborate with the design team to create a new company logo and brand identity.\r',
#    {'entities': [[0, 3, 'ASSIGNEE'], [5, 85, 'TEXT']]}],
#   ['Olivia, analyze sales data and propose strategies to increase revenue and profitability.\r',
#    {'entities': [[0, 6, 'ASSIGNEE'], [8, 87, 'TEXT']]}],
#   ['Logan, develop a project plan for launching a new product in the market.\r',
#    {'entities': [[0, 5, 'ASSIGNEE'], [7, 71, 'TEXT']]}],
#   ['Chloe, conduct a competitor analysis and provide recommendations for product differentiation.\r',
#    {'entities': [[0, 5, 'ASSIGNEE'], [7, 92, 'TEXT']]}],
#   ['Aria, review the current customer onboarding process and suggest improvements.\r',
#    {'entities': [[0, 4, 'ASSIGNEE'], [6, 77, 'TEXT']]}],
#   ['Harper, conduct a usability testing session for our website and identify areas for improvement.\r',
#    {'entities': [[0, 6, 'ASSIGNEE'], [8, 94, 'TEXT']]}],
#   ['Evelyn, research and compile a list of potential conference venues for our upcoming event.\r',
#    {'entities': [[0, 6, 'ASSIGNEE'], [8, 89, 'TEXT']]}],
#   ['Leo, create a timeline and project plan for the website redesign project.\r',
#    {'entities': [[0, 3, 'ASSIGNEE'], [5, 72, 'TEXT']]}],
#   ['Zara, coordinate with the logistics team to arrange transportation for the offsite team-building event.\r',
#    {'entities': [[0, 4, 'ASSIGNEE'], [6, 102, 'TEXT']]}],
#   ['Felix, conduct a competitor analysis and provide recommendations for improving our product pricing strategy.\r',
#    {'entities': [[0, 5, 'ASSIGNEE'], [7, 107, 'TEXT']]}],
#   ['Isabella, prepare a training module on effective communication skills for the new hires.\r',
#    {'entities': [[0, 8, 'ASSIGNEE'], [10, 87, 'TEXT']]}],
#   ['Luna, collaborate with the finance team to create a budget proposal for the upcoming fiscal year.\r',
#    {'entities': [[0, 4, 'ASSIGNEE'], [6, 96, 'TEXT']]}],
#   ['Aiden, conduct a market research survey to gather insights on customer preferences and buying habits.\r',
#    {'entities': [[0, 5, 'ASSIGNEE'], [7, 100, 'TEXT']]}],
#   ['Violet, develop a social media content calendar for the next quarter, aligning with our marketing campaigns.\r',
#    {'entities': [[0, 6, 'ASSIGNEE'], [8, 107, 'TEXT']]}],
#   ['Caleb, review and optimize the current inventory management system to reduce costs and improve efficiency.\r',
#    {'entities': [[0, 5, 'ASSIGNEE'], [7, 105, 'TEXT']]}],
#   ['Avery, conduct user testing sessions for the new mobile app and provide actionable feedback for enhancements.\r',
#    {'entities': [[0, 5, 'ASSIGNEE'], [7, 108, 'TEXT']]}],
#   ['Pamela, conduct market research on emerging trends in the fashion industry and prepare a report for our next strategy meeting.\r',
#    {'entities': [[0, 6, 'ASSIGNEE'], [8, 125, 'TEXT']]}],
#   ['Maive, create a comprehensive project plan with key milestones and deliverables for the upcoming product launch.\r',
#    {'entities': [[0, 5, 'ASSIGNEE'], [7, 111, 'TEXT']]}],
#   ['Sylvia, coordinate with the design team to develop a visually appealing and user-friendly interface for our new website.\r',
#    {'entities': [[0, 6, 'ASSIGNEE'], [8, 119, 'TEXT']]}],
#   ['Nolan, conduct a thorough analysis of customer feedback and provide recommendations for improving our customer support processes.\r',
#    {'entities': [[0, 5, 'ASSIGNEE'], [7, 128, 'TEXT']]}],
#   ['Maxwell, organize and facilitate a training workshop on effective team collaboration and communication.\r',
#    {'entities': [[0, 7, 'ASSIGNEE'], [9, 102, 'TEXT']]}],
#   ['Elijah, collaborate with the sales team to develop a targeted marketing campaign for our new product line.\r',
#    {'entities': [[0, 6, 'ASSIGNEE'], [8, 105, 'TEXT']]}],
#   ['Liam, conduct a cost-benefit analysis for implementing a new CRM system and present your findings in the next team meeting.\r',
#    {'entities': [[0, 4, 'ASSIGNEE'], [6, 122, 'TEXT']]}],
#   ['Aria, create a detailed project timeline with deadlines and dependencies for the upcoming client deliverables.\r',
#    {'entities': [[0, 4, 'ASSIGNEE'], [6, 109, 'TEXT']]}],
#   ["Leo, conduct a competitive analysis of our key competitors' pricing strategies and propose adjustments to our pricing model.\r",
#    {'entities': [[0, 3, 'TEXT'], [5, 123, 'ASSIGNEE']]}],
#   ['... Alice, can you take the UX bug? ...\r',
#    {'entities': [[4, 9, 'ASSIGNEE'], [28, 34, 'TEXT']]}],
#   ['Mohit, conduct a customer satisfaction survey and analyze the results for actionable insights.\r',
#    {'entities': [[0, 5, 'ASSIGNEE'], [17, 93, 'TEXT']]}],
#   ['Lisa, we need someone detail-oriented for this task. Can I count on you to oversee the quality assurance process?\r',
#    {'entities': [[0, 4, 'ASSIGNEE'], [75, 112, 'TEXT']]}],
#   ['John, I would like to delegate the task of preparing the sales presentation for our upcoming client meeting to you\r',
#    {'entities': [[0, 4, 'ASSIGNEE'], [43, 107, 'TEXT']]}],
#   ["Jennifer, I'd like you to allow each team member to assign themselves a task aligned with our project goals\r",
#    {'entities': []}],
#   ["I'd like to assign Jacob a task in a different department to broaden his skill set.",
#    {'entities': [[19, 24, 'ASSIGNEE'], [37, 82, 'TEXT']]}],
#   ['Avery, research and recommend the most suitable software tools for streamlining our workflow and enhancing team productivity.\r',
#    {'entities': [[0, 5, 'ASSIGNEE'], [7, 124, 'TEXT']]}],
#   ['Emily, lead the brainstorming session for our new product ideas and present the top three concepts to the team.\r',
#    {'entities': [[0, 5, 'ASSIGNEE'], [7, 110, 'TEXT']]}],
#   ["Nathan, conduct a SWOT analysis of our company's marketing strategies and identify potential areas for improvement.\r",
#    {'entities': [[0, 6, 'ASSIGNEE'], [8, 114, 'TEXT']]}],
#   ['Sophia, coordinate with the engineering team to develop a prototype for the new feature and conduct user testing.\r',
#    {'entities': [[0, 6, 'ASSIGNEE'], [8, 112, 'TEXT']]}],
#   ['Evelyn, prepare a comprehensive financial forecast for the next quarter and present it at the board meeting.\r',
#    {'entities': [[0, 6, 'ASSIGNEE'], [8, 107, 'TEXT']]}],
#   ["Mason, review and update the company's social media strategy to enhance brand visibility and engagement.\r",
#    {'entities': [[0, 5, 'ASSIGNEE'], [7, 103, 'TEXT']]}],
#   ['Scarlett, collaborate with the HR department to develop a training program for new employees and onboard them effectively.\r',
#    {'entities': [[0, 8, 'ASSIGNEE'], [10, 121, 'TEXT']]}],
#   ['Daniel, conduct market research on emerging trends in the tech industry and identify potential business opportunities.\r',
#    {'entities': [[0, 6, 'ASSIGNEE'], [8, 117, 'TEXT']]}],
#   ['Grace, analyze customer feedback data to identify patterns and propose actionable insights for improving our product.\r',
#    {'entities': [[0, 5, 'ASSIGNEE'], [7, 116, 'TEXT']]}],
#   ['Lily, create a comprehensive project plan for the upcoming conference and ensure all deliverables are on track.\r',
#    {'entities': [[0, 4, 'ASSIGNEE'], [6, 110, 'TEXT']]}],
#   ['William, lead the customer service team in developing strategies to enhance customer satisfaction and loyalty.\r',
#    {'entities': [[0, 7, 'ASSIGNEE'], [9, 109, 'TEXT']]}],
#   ['Nayanjit, Build a model that Identify action items from meeting transcripts\r',
#    {'entities': [[0, 8, 'ASSIGNEE'], [10, 75, 'TEXT']]}],
#   ['', {'entities': []}]]}

# %%
train_data = data['annotations']
train_data = [tuple(i) for i in train_data]

# %%
train_data
# Out:
# [('I have an important task that needs to be assigned to someone. It involves analyzing the market trends and preparing a report.\r',
#   {'entities': [[75, 125, 'TEXT']]}),
#  ('We need someone to take charge of the project management tasks for the upcoming product launch. Any volunteers?\r',
#   {'entities': [[38, 56, 'TEXT']]}),
#  ('I would like to assign the task of conducting user research and gathering feedback to John. Are you available, John?\r',
#   {'entities': [[46, 82, 'TEXT']]}),
#  ("As discussed earlier, we need to assign the coding tasks for the new feature implementation. Let's distribute them among the development team.\r",
#   {'entities': [[44, 92, 'TEXT']]}),
#  ('We have an urgent task of organizing the client meeting next week. Can someone from the sales team take care of it?\r',
#   {'entities': [[26, 55, 'TEXT']]}),
#  ("We have a task to prepare a detailed project plan. Let's assign this task to someone from the project management team.\r",
#   {'entities': [[18, 50, 'TEXT']]}),
#  ('We need to assign someone to conduct market research and gather insights for our upcoming product launch.\r',
#   {'entities': [[29, 104, 'TEXT']]}),
#  ('I propose we assign the task of creating a presentation for the client meeting to one of our design experts.\r',
#   {'entities': [[32, 78, 'TEXT']]}),
#  ('We have a task to review and finalize the budget for the next fiscal year. Who can take charge of this task?\r',
#   {'entities': [[18, 74, 'TEXT']]}),
#  ("Let's assign the task of coordinating logistics and travel arrangements for the upcoming conference to our admin team.\r",
#   {'entities': [[25, 71, 'TEXT']]}),
#  ('We need someone to lead the customer feedback analysis task and provide actionable insights to improve our product.\r',
#   {'entities': [[19, 114, 'TEXT']]}),
#  ("It's crucial that we assign someone to conduct user testing and gather feedback on the new app interface.\r",
#   {'entities': [[39, 104, 'TEXT']]}),
#  ('We have a task to research and recommend potential vendors for our upcoming software development project.\r',
#   {'entities': [[18, 58, 'TEXT']]}),
#  ("Let's assign the task of drafting the project proposal to someone with strong writing and research skills.\r",
#   {'entities': [[25, 54, 'TEXT']]}),
#  ('We need to assign someone to coordinate with the sales team and gather requirements for the new CRM system.\r',
#   {'entities': [[29, 106, 'TEXT']]}),
#  ('We should assign someone to conduct market research and identify potential competitors in the industry.\r',
#   {'entities': [[28, 102, 'TEXT']]}),
#  ("Let's assign the task of preparing the financial projections for the next quarter to someone with expertise in financial analysis.\r",
#   {'entities': [[25, 81, 'TEXT']]}),
#  ('We need to assign someone to coordinate with the design team and create a mockup for the new website layout.\r',
#   {'entities': [[29, 107, 'TEXT']]}),
#  ("It's important that we assign someone to lead the project management task and ensure timely delivery of milestones.\r",
#   {'entities': [[41, 73, 'TEXT']]}),
#  ("We should assign someone to handle the logistics and coordinate the team's travel arrangements for the upcoming conference.\r",
#   {'entities': [[28, 94, 'TEXT']]}),
#  ("Let's assign someone to conduct user testing and gather feedback on the new mobile app interface.\r",
#   {'entities': [[24, 96, 'TEXT']]}),
#  ('We need to assign someone to write the project proposal and include the timeline and deliverables.\r',
#   {'entities': [[29, 97, 'TEXT']]}),
#  ('It would be great if someone can take on the task of creating the presentation slides for the client pitch.\r',
#   {'entities': [[53, 106, 'TEXT']]}),
#  ('We should assign someone to review the customer feedback and identify areas for product improvement.\r',
#   {'entities': [[28, 99, 'TEXT']]}),
#  ("Let's assign someone to coordinate with the legal team and draft the contract for the new partnership.\r",
#   {'entities': [[24, 101, 'TEXT']]}),
#  ('We need to assign someone to lead the recruitment process and screen potential candidates for the open positions.\r',
#   {'entities': [[29, 112, 'TEXT']]}),
#  ("It's crucial that we assign someone to handle the budgeting and financial forecasting for the project.\r",
#   {'entities': [[39, 101, 'TEXT']]}),
#  ('We should assign someone to analyze market trends and competitor strategies to inform our marketing strategy.\r',
#   {'entities': [[28, 108, 'TEXT']]}),
#  ("Let's assign someone to conduct a risk assessment and develop a mitigation plan for the project.\r",
#   {'entities': [[24, 95, 'TEXT']]}),
#  ('We need to assign someone to coordinate with the IT department and ensure smooth implementation of the new software.\r',
#   {'entities': [[29, 115, 'TEXT']]}),
#  ('We should assign someone to conduct a market research analysis and identify potential target demographics.\r',
#   {'entities': [[28, 105, 'TEXT']]}),
#  ("Let's assign someone to schedule and coordinate meetings with key stakeholders for the upcoming project.\r",
#   {'entities': [[24, 78, 'TEXT']]}),
#  ('We need to assign someone to review and update the project documentation to reflect the latest changes.\r',
#   {'entities': [[29, 102, 'TEXT']]}),
#  ('It would be great if someone can take on the task of preparing the agenda for the next team meeting.\r',
#   {'entities': [[53, 73, 'TEXT']]}),
#  ('We should assign someone to conduct a competitive analysis and benchmark our product against industry leaders.\r',
#   {'entities': [[28, 109, 'TEXT']]}),
#  ("Let's assign someone to lead the user experience design and ensure a seamless interface for our customers.\r",
#   {'entities': [[24, 105, 'TEXT']]}),
#  ('We need to assign someone to manage the social media accounts and create engaging content for our followers.\r',
#   {'entities': [[29, 107, 'TEXT']]}),
#  ("It's crucial that we assign someone to coordinate the logistics and travel arrangements for the upcoming conference.\r",
#   {'entities': [[39, 87, 'TEXT']]}),
#  ('We should assign someone to monitor and analyze key performance indicators to track the success of our marketing campaigns.\r',
#   {'entities': [[28, 122, 'TEXT']]}),
#  ("Let's assign someone to conduct a usability test and gather feedback on the new website design.\r",
#   {'entities': [[24, 94, 'TEXT']]}),
#  ('Schedule and coordinate meetings with key stakeholders for the upcoming project.\r',
#   {'entities': [[0, 54, 'TEXT']]}),
#  ('Review and update project documentation to reflect the latest changes.\r',
#   {'entities': [[0, 69, 'TEXT']]}),
#  ('Prepare the agenda for the next team meeting.\r',
#   {'entities': [[0, 18, 'TEXT']]}),
#  ('Conduct a competitive analysis and benchmark our product against industry leaders.\r',
#   {'entities': [[10, 81, 'TEXT']]}),
#  ('Lead the user experience design and ensure a seamless interface.\r',
#   {'entities': [[0, 63, 'TEXT']]}),
#  ('Manage social media accounts and create engaging content for followers.\r',
#   {'entities': [[0, 70, 'TEXT']]}),
#  ('Coordinate logistics and travel arrangements for the upcoming conference.\r',
#   {'entities': [[0, 44, 'TEXT']]}),
#  ('Monitor and analyze key performance indicators for marketing campaigns.\r',
#   {'entities': [[0, 70, 'TEXT']]}),
#  ('Conduct a usability test and gather feedback on the new website design.\r',
#   {'entities': [[10, 70, 'TEXT']]}),
#  ('Develop a project timeline and assign milestones to team members.\r',
#   {'entities': [[0, 64, 'TEXT']]}),
#  ('Task assigned: Research and propose new software tools for process automation.\r',
#   {'entities': [[15, 78, 'TEXT']]}),
#  ('Create a detailed project budget and allocate resources accordingly.\r',
#   {'entities': [[9, 67, 'TEXT']]}),
#  ("Conduct training sessions to enhance team members' technical skills.\r",
#   {'entities': [[8, 67, 'TEXT']]}),
#  ('Draft a comprehensive project proposal outlining objectives and deliverables.\r',
#   {'entities': [[0, 76, 'TEXT']]}),
#  ('Implement a data backup and recovery plan to ensure data security.\r',
#   {'entities': [[0, 65, 'TEXT']]}),
#  ('Develop a customer satisfaction survey and analyze the results.\r',
#   {'entities': [[0, 62, 'TEXT']]}),
#  ('Task assigned: Create a content calendar for social media posts and schedule content.\r',
#   {'entities': [[15, 76, 'TEXT']]}),
#  ('Conduct interviews to hire additional team members for project support.\r',
#   {'entities': [[8, 70, 'TEXT']]}),
#  ('Establish a communication plan to ensure effective team collaboration.\r',
#   {'entities': [[0, 69, 'TEXT']]}),
#  ('Identify potential target demographics.\r',
#   {'entities': [[0, 38, 'TEXT']]}),
#  ('Could you please prepare a project timeline and deliverables for client review?\r',
#   {'entities': []}),
#  ("We need your expertise to conduct a competitive analysis and present your findings in next week's meeting.\r",
#   {'entities': [[26, 82, 'TEXT']]}),
#  ('It would be great if you could research and propose new marketing strategies to attract our target audience.\r',
#   {'entities': [[31, 107, 'TEXT']]}),
#  ('Your task is to update the website content and ensure it aligns with the latest brand guidelines.\r',
#   {'entities': [[16, 96, 'TEXT']]}),
#  ('Can you coordinate with the sales team to finalize pricing for the upcoming product launch?\r',
#   {'entities': [[8, 90, 'TEXT']]}),
#  ('We would like you to create a comprehensive project plan with clear milestones and deadlines.\r',
#   {'entities': [[21, 56, 'TEXT']]}),
#  ('Could you please conduct market research to identify potential expansion opportunities in new regions?\r',
#   {'entities': [[17, 101, 'TEXT']]}),
#  ('Your action item is to develop a customer retention strategy and present it to the leadership team.\r',
#   {'entities': [[23, 98, 'TEXT']]}),
#  ('It would be great if you could analyze customer feedback data and identify areas for product improvement.\r',
#   {'entities': [[31, 104, 'TEXT']]}),
#  ('Can you prepare a detailed budget proposal for the upcoming marketing campaign?\r',
#   {'entities': [[8, 78, 'TEXT']]}),
#  ('Your task is to coordinate logistics and ensure a smooth execution of the upcoming company event.\r',
#   {'entities': [[16, 96, 'TEXT']]}),
#  ('We need your expertise to research and recommend new software tools to streamline our internal processes.\r',
#   {'entities': [[26, 104, 'TEXT']]}),
#  ('It would be great if you could conduct user testing sessions to gather feedback on the latest product prototype.\r',
#   {'entities': [[31, 79, 'TEXT']]}),
#  ('Can you develop a content marketing strategy to increase our brand visibility and engagement?\r',
#   {'entities': [[18, 92, 'TEXT']]}),
#  ('Your task is to implement a data tracking system to monitor key performance indicators.\r',
#   {'entities': [[28, 86, 'TEXT']]}),
#  ('Could you please create a comprehensive training program for new hires to ensure a smooth onboarding process?\r',
#   {'entities': [[17, 108, 'TEXT']]}),
#  ('We need your expertise to establish key performance metrics and benchmarks for the sales team.\r',
#   {'entities': [[26, 93, 'TEXT']]}),
#  ('Your task is to develop a social media content calendar for the next quarter.\r',
#   {'entities': [[26, 76, 'TEXT']]}),
#  ('It would be great if you could conduct interviews to identify and hire a qualified candidate for the vacant position.\r',
#   {'entities': [[39, 116, 'TEXT']]}),
#  ('Can you conduct a SWOT analysis to identify our strengths, weaknesses, opportunities, and threats?\r',
#   {'entities': [[18, 97, 'TEXT']]}),
#  ('Could you please perform data analysis to identify key trends and insights for our upcoming report?\r',
#   {'entities': [[25, 98, 'TEXT']]}),
#  ('We need you to create a detailed project timeline and allocate resources accordingly.\r',
#   {'entities': [[24, 84, 'TEXT']]}),
#  ('It would be great if you could develop a marketing strategy to promote our new product launch.\r',
#   {'entities': [[31, 93, 'TEXT']]}),
#  ('Your task is to draft a proposal outlining potential cost-saving measures for the department.\r',
#   {'entities': [[24, 92, 'TEXT']]}),
#  ('Can you coordinate with the design team to create visually appealing graphics for our upcoming presentation?\r',
#   {'entities': [[28, 107, 'TEXT']]}),
#  ('We would like you to conduct market research and prepare a competitive analysis report.\r',
#   {'entities': [[29, 86, 'TEXT']]}),
#  ('Could you please review the current processes and suggest areas for optimization?\r',
#   {'entities': [[17, 80, 'TEXT']]}),
#  ('Your action item is to create a customer survey and gather feedback on our latest product release.\r',
#   {'entities': [[32, 97, 'TEXT']]}),
#  ('It would be great if you could develop a training program for new employees to ensure a smooth onboarding process.\r',
#   {'entities': [[31, 113, 'TEXT']]}),
#  ('Can you coordinate with the IT department to resolve technical issues related to the software upgrade?\r',
#   {'entities': [[8, 101, 'TEXT']]}),
#  ('Your task is to prepare a presentation summarizing the key findings from the recent market research study.\r',
#   {'entities': [[16, 105, 'TEXT']]}),
#  ('We need you to analyze financial data and provide recommendations for cost reduction.\r',
#   {'entities': [[15, 84, 'TEXT']]}),
#  ('It would be great if you could coordinate logistics for the upcoming team offsite event.\r',
#   {'entities': [[31, 87, 'TEXT']]}),
#  ('Can you review the current social media strategy and propose improvements to increase engagement?\r',
#   {'entities': [[8, 96, 'TEXT']]}),
#  ('Your task is to conduct user testing sessions to gather feedback on the new website design.\r',
#   {'entities': [[16, 90, 'TEXT']]}),
#  ('Could you please prepare a detailed project plan for the upcoming product launch?\r',
#   {'entities': [[17, 80, 'TEXT']]}),
#  ('We need your expertise to develop a content calendar for the company blog.\r',
#   {'entities': [[26, 73, 'TEXT']]}),
#  ('Your task is to conduct interviews and assist in the hiring process for a new team member.\r',
#   {'entities': [[24, 89, 'TEXT']]}),
#  ('It would be great if you could research and recommend software solutions to improve productivity.\r',
#   {'entities': [[31, 96, 'TEXT']]}),
#  ('Can you conduct a customer satisfaction survey and analyze the results for actionable insights?\r',
#   {'entities': [[18, 94, 'TEXT']]}),
#  ('Mohit, conduct a customer satisfaction survey and analyze the results for actionable insights.\r',
#   {'entities': [[17, 93, 'TEXT']]}),
#  ('Sophie, create a detailed project timeline and allocate resources accordingly.\r',
#   {'entities': [[17, 77, 'TEXT']]}),
#  ('Emily, develop a marketing strategy to promote our new product launch.\r',
#   {'entities': [[17, 69, 'TEXT']]}),
#  ('Jacob, draft a proposal outlining potential cost-saving measures for the department.\r',
#   {'entities': [[15, 83, 'TEXT']]}),
#  ('Oliver, coordinate with the design team to create visually appealing graphics for our upcoming presentation.\r',
#   {'entities': [[8, 107, 'TEXT']]}),
#  ('Emma, conduct market research and prepare a competitive analysis report.\r',
#   {'entities': [[6, 71, 'TEXT']]}),
#  ('Noah, review the current processes and suggest areas for optimization.\r',
#   {'entities': [[6, 69, 'TEXT']]}),
#  ('Ava, create a customer survey and gather feedback on our latest product release.\r',
#   {'entities': [[0, 3, 'ASSIGNEE'], [14, 79, 'TEXT']]}),
#  ('William, develop a training program for new employees to ensure a smooth onboarding process.\r',
#   {'entities': [[0, 7, 'ASSIGNEE'], [9, 91, 'TEXT']]}),
#  ('Liam, coordinate with the IT department to resolve technical issues related to the software upgrade.\r',
#   {'entities': [[0, 4, 'ASSIGNEE'], [6, 99, 'TEXT']]}),
#  ('Ella, prepare a presentation summarizing the key findings from the recent market research study.\r',
#   {'entities': [[0, 4, 'ASSIGNEE'], [6, 95, 'TEXT']]}),
#  ('Sophia, analyze financial data and provide recommendations for cost reduction.\r',
#   {'entities': [[0, 6, 'ASSIGNEE'], [8, 77, 'TEXT']]}),
#  ('Michael, coordinate logistics for the upcoming team offsite event.\r',
#   {'entities': [[0, 7, 'ASSIGNEE'], [9, 65, 'TEXT']]}),
#  ('Grace, review the current social media strategy and propose improvements to increase engagement.\r',
#   {'entities': []}),
#  ('Daniel, conduct usability testing for the new website design.\r',
#   {'entities': [[0, 6, 'ASSIGNEE'], [8, 60, 'TEXT']]}),
#  ('Ethan, research and identify potential partnership opportunities with industry influencers.\r',
#   {'entities': [[0, 5, 'ASSIGNEE'], [7, 90, 'TEXT']]}),
#  ('Mia, draft a press release announcing our latest product launch.\r',
#   {'entities': [[0, 3, 'ASSIGNEE'], [5, 63, 'TEXT']]}),
#  ('Olivia, compile and analyze customer feedback to identify common pain points.\r',
#   {'entities': [[0, 6, 'ASSIGNEE'], [8, 76, 'TEXT']]}),
#  ('Logan, collaborate with the sales team to develop a new pricing strategy.\r',
#   {'entities': [[0, 5, 'ASSIGNEE'], [7, 72, 'TEXT']]}),
#  ('Chloe, create a comprehensive training manual for new employees.\r',
#   {'entities': [[0, 5, 'ASSIGNEE'], [7, 63, 'TEXT']]}),
#  ('Emily, coordinate with the design team to create a visually appealing user interface.\r',
#   {'entities': [[0, 5, 'ASSIGNEE'], [7, 84, 'TEXT']]}),
#  ("Owen, conduct a competitive analysis of our main competitors' marketing campaigns.\r",
#   {'entities': [[0, 4, 'ASSIGNEE'], [6, 81, 'ASSIGNEE']]}),
#  ('Zoe, organize and lead a brainstorming session\r',
#   {'entities': [[0, 3, 'ASSIGNEE'], [5, 46, 'TEXT']]}),
#  ('Nathan, prepare a comprehensive sales report for the quarter.\r',
#   {'entities': [[0, 6, 'ASSIGNEE'], [8, 60, 'TEXT']]}),
#  ("Sophie, conduct a thorough analysis of our website's user experience and suggest improvements.\r",
#   {'entities': [[0, 6, 'ASSIGNEE'], [8, 93, 'TEXT']]}),
#  ('Emily, create a detailed project plan outlining milestones and deliverables.\r',
#   {'entities': [[0, 5, 'ASSIGNEE'], [7, 75, 'TEXT']]}),
#  ('Jacob, research and recommend a customer relationship management (CRM) software for the team.\r',
#   {'entities': [[0, 5, 'ASSIGNEE'], [7, 92, 'TEXT']]}),
#  ('Oliver, prepare a presentation on the latest market trends and their impact on our industry.\r',
#   {'entities': [[0, 6, 'ASSIGNEE'], [8, 91, 'TEXT']]}),
#  ('Emma, coordinate with the content team to develop engaging blog posts for our target audience.\r',
#   {'entities': [[0, 4, 'ASSIGNEE'], [6, 93, 'TEXT']]}),
#  ('Noah, analyze the data from our recent advertising campaign and provide insights on its effectiveness.\r',
#   {'entities': [[0, 4, 'ASSIGNEE'], [6, 101, 'TEXT']]}),
#  ('Ava, conduct a competitor analysis and identify potential opportunities for product differentiation.\r',
#   {'entities': [[0, 3, 'ASSIGNEE'], [5, 99, 'TEXT']]}),
#  ('William, create a training manual for our new customer service representatives.\r',
#   {'entities': [[0, 7, 'ASSIGNEE'], [9, 78, 'TEXT']]}),
#  ('Liam, develop a social media content calendar for the upcoming month.\r',
#   {'entities': [[0, 4, 'ASSIGNEE'], [6, 68, 'TEXT']]}),
#  ('Ella, review and optimize our email marketing campaigns to increase open and click-through rates.\r',
#   {'entities': [[0, 4, 'ASSIGNEE'], [6, 96, 'TEXT']]}),
#  ('Sophia, coordinate with the HR department to streamline our recruitment process.\r',
#   {'entities': [[0, 6, 'ASSIGNEE'], [8, 79, 'TEXT']]}),
#  ('Michael, conduct a cost analysis of our manufacturing processes and propose cost-saving measures.\r',
#   {'entities': [[0, 7, 'ASSIGNEE'], [9, 96, 'TEXT']]}),
#  ('Grace, organize a team-building event to enhance collaboration and morale within the team.\r',
#   {'entities': [[0, 5, 'ASSIGNEE'], [7, 89, 'TEXT']]}),
#  ('Daniel, conduct a market research survey to gather insights on customer preferences and expectations.\r',
#   {'entities': [[0, 6, 'ASSIGNEE'], [8, 100, 'TEXT']]}),
#  ('Ethan, develop a comprehensive onboarding program for new hires.\r',
#   {'entities': [[0, 5, 'ASSIGNEE'], [7, 63, 'TEXT']]}),
#  ('Mia, create a visually appealing presentation template for future client meetings.\r',
#   {'entities': [[0, 3, 'ASSIGNEE'], [5, 81, 'TEXT']]}),
#  ('Olivia, analyze website traffic data and propose strategies to increase conversion rates.\r',
#   {'entities': [[0, 6, 'ASSIGNEE'], [8, 88, 'TEXT']]}),
#  ('Logan, collaborate with the finance team to develop a budget for an upcoming project.\r',
#   {'entities': [[0, 5, 'ASSIGNEE'], [7, 84, 'TEXT']]}),
#  ('Chloe, conduct a product demo for potential clients and gather feedback for product improvement.\r',
#   {'entities': [[0, 5, 'ASSIGNEE'], [7, 95, 'TEXT']]}),
#  ('Emily, coordinate with the design team to create a visually appealing user interface for the new software.\r',
#   {'entities': [[0, 5, 'ASSIGNEE'], [7, 105, 'TEXT']]}),
#  ('Owen, research and propose a new vendor for our office supplies to reduce\r',
#   {'entities': [[0, 4, 'ASSIGNEE'], [6, 73, 'TEXT']]}),
#  ('Nathan, conduct a thorough analysis of our customer feedback and suggest improvements for our products.\r',
#   {'entities': [[0, 6, 'ASSIGNEE'], [8, 102, 'TEXT']]}),
#  ('Sophie, create a marketing campaign targeting our new customer segment.\r',
#   {'entities': [[0, 6, 'ASSIGNEE'], [8, 70, 'TEXT']]}),
#  ('Emily, prepare a presentation on the latest industry trends and their impact on our business.\r',
#   {'entities': [[0, 5, 'ASSIGNEE'], [7, 92, 'TEXT']]}),
#  ('Jacob, research and recommend a project management tool for better team collaboration.\r',
#   {'entities': [[0, 5, 'ASSIGNEE'], [7, 85, 'TEXT']]}),
#  ('Oliver, develop a training program for our sales team to enhance their negotiation skills.\r',
#   {'entities': [[0, 6, 'ASSIGNEE'], [8, 89, 'TEXT']]}),
#  ('Emma, coordinate with the IT department to implement a new data analytics system.\r',
#   {'entities': [[0, 4, 'ASSIGNEE'], [6, 80, 'TEXT']]}),
#  ('Noah, analyze customer feedback and propose improvements to our product packaging.\r',
#   {'entities': [[0, 4, 'ASSIGNEE'], [6, 81, 'TEXT']]}),
#  ('Ava, conduct market research to identify potential new target markets for our services.\r',
#   {'entities': [[0, 3, 'ASSIGNEE'], [5, 86, 'TEXT']]}),
#  ('William, prepare a cost-benefit analysis for investing in new equipment for the production line.\r',
#   {'entities': [[0, 7, 'ASSIGNEE'], [9, 95, 'TEXT']]}),
#  ('Liam, develop a social media advertising campaign to increase brand awareness.\r',
#   {'entities': [[0, 4, 'ASSIGNEE'], [6, 77, 'TEXT']]}),
#  ("Ella, review and update our company's privacy policy to comply with new regulations.\r",
#   {'entities': [[0, 4, 'ASSIGNEE'], [6, 83, 'TEXT']]}),
#  ('Sophia, coordinate with the HR department to design a comprehensive employee wellness program.\r',
#   {'entities': [[0, 6, 'ASSIGNEE'], [8, 93, 'TEXT']]}),
#  ('Michael, conduct a market analysis to identify potential business expansion opportunities.\r',
#   {'entities': [[0, 7, 'ASSIGNEE'], [9, 89, 'TEXT']]}),
#  ('Grace, create a customer loyalty program to increase customer retention rates.\r',
#   {'entities': [[0, 5, 'ASSIGNEE'], [7, 77, 'TEXT']]}),
#  ('Daniel, develop a content marketing strategy to attract and engage our target audience.\r',
#   {'entities': [[0, 6, 'ASSIGNEE'], [8, 86, 'TEXT']]}),
#  ('Ethan, research and recommend a customer support software for better customer service management.\r',
#   {'entities': [[0, 5, 'ASSIGNEE'], [7, 96, 'TEXT']]}),
#  ('Mia, collaborate with the design team to create a new company logo and brand identity.\r',
#   {'entities': [[0, 3, 'ASSIGNEE'], [5, 85, 'TEXT']]}),
#  ('Olivia, analyze sales data and propose strategies to increase revenue and profitability.\r',
#   {'entities': [[0, 6, 'ASSIGNEE'], [8, 87, 'TEXT']]}),
#  ('Logan, develop a project plan for launching a new product in the market.\r',
#   {'entities': [[0, 5, 'ASSIGNEE'], [7, 71, 'TEXT']]}),
#  ('Chloe, conduct a competitor analysis and provide recommendations for product differentiation.\r',
#   {'entities': [[0, 5, 'ASSIGNEE'], [7, 93, 'TEXT']]}),
#  ('Aria, review the current customer onboarding process and suggest improvements.\r',
#   {'entities': [[0, 4, 'ASSIGNEE'], [6, 77, 'TEXT']]}),
#  ('Harper, conduct a usability testing session for our website and identify areas for improvement.\r',
#   {'entities': [[0, 6, 'ASSIGNEE'], [8, 94, 'TEXT']]}),
#  ('Nathan, conduct a thorough analysis of our customer feedback and suggest improvements for our products.\r',
#   {'entities': [[0, 6, 'ASSIGNEE'], [8, 102, 'TEXT']]}),
#  ('Sophie, create a marketing campaign targeting our new customer segment.\r',
#   {'entities': [[0, 6, 'ASSIGNEE'], [8, 70, 'TEXT']]}),
#  ('Emily, prepare a presentation on the latest industry trends and their impact on our business.\r',
#   {'entities': [[0, 5, 'ASSIGNEE'], [7, 92, 'TEXT']]}),
#  ('Jacob, research and recommend a project management tool for better team collaboration.\r',
#   {'entities': [[0, 5, 'ASSIGNEE'], [7, 85, 'TEXT']]}),
#  ('Oliver, develop a training program for our sales team to enhance their negotiation skills.\r',
#   {'entities': [[0, 6, 'ASSIGNEE'], [8, 89, 'TEXT']]}),
#  ('Emma, coordinate with the IT department to implement a new data analytics system.\r',
#   {'entities': [[0, 4, 'ASSIGNEE'], [6, 80, 'TEXT']]}),
#  ('Noah, analyze customer feedback and propose improvements to our product packaging.\r',
#   {'entities': [[0, 4, 'ASSIGNEE'], [6, 81, 'TEXT']]}),
#  ('Ava, conduct market research to identify potential new target markets for our services.\r',
#   {'entities': [[0, 3, 'ASSIGNEE'], [5, 86, 'TEXT']]}),
#  ('William, prepare a cost-benefit analysis for investing in new equipment for the production line.\r',
#   {'entities': [[0, 7, 'ASSIGNEE'], [9, 95, 'TEXT']]}),
#  ('Liam, develop a social media advertising campaign to increase brand awareness.\r',
#   {'entities': [[0, 4, 'ASSIGNEE'], [6, 77, 'TEXT']]}),
#  ("Ella, review and update our company's privacy policy to comply with new regulations.\r",
#   {'entities': [[0, 4, 'ASSIGNEE'], [6, 83, 'TEXT']]}),
#  ('Sophia, coordinate with the HR department to design a comprehensive employee wellness program.\r',
#   {'entities': [[0, 6, 'ASSIGNEE'], [8, 93, 'TEXT']]}),
#  ('Michael, conduct a market analysis to identify potential business expansion opportunities.\r',
#   {'entities': [[0, 7, 'ASSIGNEE'], [9, 89, 'TEXT']]}),
#  ('Grace, create a customer loyalty program to increase customer retention rates.\r',
#   {'entities': [[0, 5, 'ASSIGNEE'], [7, 77, 'TEXT']]}),
#  ('Daniel, develop a content marketing strategy to attract and engage our target audience.\r',
#   {'entities': [[0, 6, 'ASSIGNEE'], [8, 86, 'TEXT']]}),
#  ('Ethan, research and recommend a customer support software for better customer service management.\r',
#   {'entities': [[0, 5, 'ASSIGNEE'], [7, 96, 'TEXT']]}),
#  ('Mia, collaborate with the design team to create a new company logo and brand identity.\r',
#   {'entities': [[0, 3, 'ASSIGNEE'], [5, 85, 'TEXT']]}),
#  ('Olivia, analyze sales data and propose strategies to increase revenue and profitability.\r',
#   {'entities': [[0, 6, 'ASSIGNEE'], [8, 87, 'TEXT']]}),
#  ('Logan, develop a project plan for launching a new product in the market.\r',
#   {'entities': [[0, 5, 'ASSIGNEE'], [7, 71, 'TEXT']]}),
#  ('Chloe, conduct a competitor analysis and provide recommendations for product differentiation.\r',
#   {'entities': [[0, 5, 'ASSIGNEE'], [7, 92, 'TEXT']]}),
#  ('Aria, review the current customer onboarding process and suggest improvements.\r',
#   {'entities': [[0, 4, 'ASSIGNEE'], [6, 77, 'TEXT']]}),
#  ('Harper, conduct a usability testing session for our website and identify areas for improvement.\r',
#   {'entities': [[0, 6, 'ASSIGNEE'], [8, 94, 'TEXT']]}),
#  ('Evelyn, research and compile a list of potential conference venues for our upcoming event.\r',
#   {'entities': [[0, 6, 'ASSIGNEE'], [8, 89, 'TEXT']]}),
#  ('Leo, create a timeline and project plan for the website redesign project.\r',
#   {'entities': [[0, 3, 'ASSIGNEE'], [5, 72, 'TEXT']]}),
#  ('Zara, coordinate with the logistics team to arrange transportation for the offsite team-building event.\r',
#   {'entities': [[0, 4, 'ASSIGNEE'], [6, 102, 'TEXT']]}),
#  ('Felix, conduct a competitor analysis and provide recommendations for improving our product pricing strategy.\r',
#   {'entities': [[0, 5, 'ASSIGNEE'], [7, 107, 'TEXT']]}),
#  ('Isabella, prepare a training module on effective communication skills for the new hires.\r',
#   {'entities': [[0, 8, 'ASSIGNEE'], [10, 87, 'TEXT']]}),
#  ('Luna, collaborate with the finance team to create a budget proposal for the upcoming fiscal year.\r',
#   {'entities': [[0, 4, 'ASSIGNEE'], [6, 96, 'TEXT']]}),
#  ('Aiden, conduct a market research survey to gather insights on customer preferences and buying habits.\r',
#   {'entities': [[0, 5, 'ASSIGNEE'], [7, 100, 'TEXT']]}),
#  ('Violet, develop a social media content calendar for the next quarter, aligning with our marketing campaigns.\r',
#   {'entities': [[0, 6, 'ASSIGNEE'], [8, 107, 'TEXT']]}),
#  ('Caleb, review and optimize the current inventory management system to reduce costs and improve efficiency.\r',
#   {'entities': [[0, 5, 'ASSIGNEE'], [7, 105, 'TEXT']]}),
#  ('Avery, conduct user testing sessions for the new mobile app and provide actionable feedback for enhancements.\r',
#   {'entities': [[0, 5, 'ASSIGNEE'], [7, 108, 'TEXT']]}),
#  ('Pamela, conduct market research on emerging trends in the fashion industry and prepare a report for our next strategy meeting.\r',
#   {'entities': [[0, 6, 'ASSIGNEE'], [8, 125, 'TEXT']]}),
#  ('Maive, create a comprehensive project plan with key milestones and deliverables for the upcoming product launch.\r',
#   {'entities': [[0, 5, 'ASSIGNEE'], [7, 111, 'TEXT']]}),
#  ('Sylvia, coordinate with the design team to develop a visually appealing and user-friendly interface for our new website.\r',
#   {'entities': [[0, 6, 'ASSIGNEE'], [8, 119, 'TEXT']]}),
#  ('Nolan, conduct a thorough analysis of customer feedback and provide recommendations for improving our customer support processes.\r',
#   {'entities': [[0, 5, 'ASSIGNEE'], [7, 128, 'TEXT']]}),
#  ('Maxwell, organize and facilitate a training workshop on effective team collaboration and communication.\r',
#   {'entities': [[0, 7, 'ASSIGNEE'], [9, 102, 'TEXT']]}),
#  ('Elijah, collaborate with the sales team to develop a targeted marketing campaign for our new product line.\r',
#   {'entities': [[0, 6, 'ASSIGNEE'], [8, 105, 'TEXT']]}),
#  ('Liam, conduct a cost-benefit analysis for implementing a new CRM system and present your findings in the next team meeting.\r',
#   {'entities': [[0, 4, 'ASSIGNEE'], [6, 122, 'TEXT']]}),
#  ('Aria, create a detailed project timeline with deadlines and dependencies for the upcoming client deliverables.\r',
#   {'entities': [[0, 4, 'ASSIGNEE'], [6, 109, 'TEXT']]}),
#  ("Leo, conduct a competitive analysis of our key competitors' pricing strategies and propose adjustments to our pricing model.\r",
#   {'entities': [[0, 3, 'TEXT'], [5, 123, 'ASSIGNEE']]}),
#  ('... Alice, can you take the UX bug? ...\r',
#   {'entities': [[4, 9, 'ASSIGNEE'], [28, 34, 'TEXT']]}),
#  ('Mohit, conduct a customer satisfaction survey and analyze the results for actionable insights.\r',
#   {'entities': [[0, 5, 'ASSIGNEE'], [17, 93, 'TEXT']]}),
#  ('Lisa, we need someone detail-oriented for this task. Can I count on you to oversee the quality assurance process?\r',
#   {'entities': [[0, 4, 'ASSIGNEE'], [75, 112, 'TEXT']]}),
#  ('John, I would like to delegate the task of preparing the sales presentation for our upcoming client meeting to you\r',
#   {'entities': [[0, 4, 'ASSIGNEE'], [43, 107, 'TEXT']]}),
#  ("Jennifer, I'd like you to allow each team member to assign themselves a task aligned with our project goals\r",
#   {'entities': []}),
#  ("I'd like to assign Jacob a task in a different department to broaden his skill set.",
#   {'entities': [[19, 24, 'ASSIGNEE'], [37, 82, 'TEXT']]}),
#  ('Avery, research and recommend the most suitable software tools for streamlining our workflow and enhancing team productivity.\r',
#   {'entities': [[0, 5, 'ASSIGNEE'], [7, 124, 'TEXT']]}),
#  ('Emily, lead the brainstorming session for our new product ideas and present the top three concepts to the team.\r',
#   {'entities': [[0, 5, 'ASSIGNEE'], [7, 110, 'TEXT']]}),
#  ("Nathan, conduct a SWOT analysis of our company's marketing strategies and identify potential areas for improvement.\r",
#   {'entities': [[0, 6, 'ASSIGNEE'], [8, 114, 'TEXT']]}),
#  ('Sophia, coordinate with the engineering team to develop a prototype for the new feature and conduct user testing.\r',
#   {'entities': [[0, 6, 'ASSIGNEE'], [8, 112, 'TEXT']]}),
#  ('Evelyn, prepare a comprehensive financial forecast for the next quarter and present it at the board meeting.\r',
#   {'entities': [[0, 6, 'ASSIGNEE'], [8, 107, 'TEXT']]}),
#  ("Mason, review and update the company's social media strategy to enhance brand visibility and engagement.\r",
#   {'entities': [[0, 5, 'ASSIGNEE'], [7, 103, 'TEXT']]}),
#  ('Scarlett, collaborate with the HR department to develop a training program for new employees and onboard them effectively.\r',
#   {'entities': [[0, 8, 'ASSIGNEE'], [10, 121, 'TEXT']]}),
#  ('Daniel, conduct market research on emerging trends in the tech industry and identify potential business opportunities.\r',
#   {'entities': [[0, 6, 'ASSIGNEE'], [8, 117, 'TEXT']]}),
#  ('Grace, analyze customer feedback data to identify patterns and propose actionable insights for improving our product.\r',
#   {'entities': [[0, 5, 'ASSIGNEE'], [7, 116, 'TEXT']]}),
#  ('Lily, create a comprehensive project plan for the upcoming conference and ensure all deliverables are on track.\r',
#   {'entities': [[0, 4, 'ASSIGNEE'], [6, 110, 'TEXT']]}),
#  ('William, lead the customer service team in developing strategies to enhance customer satisfaction and loyalty.\r',
#   {'entities': [[0, 7, 'ASSIGNEE'], [9, 109, 'TEXT']]}),
#  ('Nayanjit, Build a model that Identify action items from meeting transcripts\r',
#   {'entities': [[0, 8, 'ASSIGNEE'], [10, 75, 'TEXT']]}),
#  ('', {'entities': []})]

# %%
entity_name = ['TEXT', 'ASSIGNEE']
for i in train_data:
    if i[1]['entities'] == []:
        i[1]['entities'] = (0, 0, entity_name)
    else:
        i[1]['entities'][0] = tuple(i[1]['entities'][0])

# %% [markdown]
# ### Building .spacy file

# %%
os.chdir(r'D:\MACHINE LEARNING\Meeting Analysis\model')

# %%
nlp = spacy.load("en_core_web_lg")
db = DocBin() 
for text, annot in tqdm(train_data):
    doc = nlp.make_doc(text)
    ents = []
    try:
        for start, end, label in annot["entities"]:
            span = doc.char_span(start, end, label=label, alignment_mode="contract")
            if span is None:
                print("Skipping entity")
            else:
                ents.append(span)
    except TypeError as e:
        continue           
    doc.ents = ents 
    db.add(doc)

db.to_disk("./train.spacy")
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████| 227/227 [00:00<00:00, 2002.22it/s]

# %% [markdown]
# # For validation data

# %% [markdown]
# ### Updating the json annotaion file
#
# Making changes to the JSON annotation file as per spacy requirements

# %%
with open(r'D:\MACHINE LEARNING\Meeting Analysis\Data\val_annotations.json', 'r') as f:
    data = json.load(f)

# %%
val_data = data['annotations']
val_data = [tuple(i) for i in train_data]

# %%
entity_name = ['TEXT', 'ASSIGNEE']
for i in val_data:
    if i[1]['entities'] == []:
        i[1]['entities'] = (0, 0, entity_name)
    else:
        try:
            i[1]['entities'][0] = tuple(i[1]['entities'][0])
        except TypeError as e:
            continue

# %% [markdown]
# ### Building .spacy file

# %%
nlp = spacy.load("en_core_web_lg") # load other spacy model

db = DocBin() # create a DocBin object

for text, annot in tqdm(val_data): # data in previous format
    doc = nlp.make_doc(text) # create doc object from text
    ents = []
    try:
        for start, end, label in annot["entities"]: # add character indexes
            span = doc.char_span(start, end, label=label, alignment_mode="contract")
            if span is None:
                print("Skipping entity")
            else:
                ents.append(span)
    except TypeError as e:
        continue           
    doc.ents = ents # label the text with the ents
    db.add(doc)

db.to_disk("./validation.spacy") # save the docbin object
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████| 227/227 [00:00<00:00, 2550.31it/s]

# %%
# !python -m spacy init fill-config base_config.cfg config.cfg
# Out:
# [+] Auto-filled config with all values
# [+] Saved config
# config.cfg
# You can now add your data and train your pipeline:
# python -m spacy train config.cfg --paths.train ./train.spacy --paths.dev ./dev.spacy

# %%
# !python -m spacy train config.cfg --output ./output --paths.train ./train.spacy --paths.dev ./validation.spacy
# Out:
# [+] Created output directory: output
# [2023-06-19 19:58:15,548] [INFO] Set up nlp object from config
# [2023-06-19 19:58:15,573] [INFO] Pipeline: ['tok2vec', 'ner']
# [2023-06-19 19:58:15,584] [INFO] Created vocabulary
# D:\SOFTWARE\ANACONDA\lib\site-packages\spacy\util.py:887: UserWarning: [W095] Model 'en_core_web_lg' (3.3.0) was trained with spaCy v3.3 and may not be 100% compatible with the current version (3.5.3). If you see errors or degraded performance, download a newer compatible model or retrain your custom model with the current spaCy version. For more details and available updates, run: python -m spacy validate
#   warnings.warn(warn_msg)
# [2023-06-19 19:58:21,819] [INFO] Added vectors: en_core_web_lg
# [2023-06-19 19:58:21,860] [INFO] Finished initializing nlp object
# [2023-06-19 19:58:23,064] [INFO] Initialized pipeline components: ['tok2vec', 'ner']
# [i] Saving to output directory: output
# [i] Using CPU
#
# =========================== Initializing pipeline ===========================
# [+] Initialized pipeline
#
# ============================= Training pipeline =============================
# [i] Pipeline: ['tok2vec', 'ner']
# [i] Initial learn rate: 0.001
# E    #       LOSS TOK2VEC  LOSS NER  ENTS_F  ENTS_P  ENTS_R  SCORE
# ---  ------  ------------  --------  ------  ------  ------  ------
#   0       0          0.00     45.90    8.44    5.87   15.00    0.08
#   5     200         20.51   1658.78   90.41   89.37   91.47    0.90
#  11     400         22.32    468.73   96.66   95.42   97.94    0.97
#  20     600        140.89    455.29   96.63   96.21   97.06    0.97
#  30     800        274.83    286.39   98.39   97.96   98.82    0.98
#  42    1000         60.83    169.34   99.12   99.12   99.12    0.99
#  57    1200        278.99    129.79   99.56   99.71   99.41    1.00
#  76    1400         25.94    100.63   99.56   99.71   99.41    1.00
#  98    1600         18.92     92.89   99.56   99.41   99.71    1.00
# 125    1800         24.90    117.32   99.56   99.71   99.41    1.00
# 158    2000        149.92    178.79   99.56   99.41   99.71    1.00
# 198    2200         40.19    156.95   99.56   99.41   99.71    1.00
# 247    2400         15.57    159.61   99.56   99.41   99.71    1.00
# 297    2600         16.81    156.31   99.56   99.41   99.71    1.00
# 347    2800         19.42    150.29   99.56   99.71   99.41    1.00
# 397    3000         80.66    172.96   99.56   99.71   99.41    1.00
# 447    3200         33.65    155.05   99.56   99.41   99.71    1.00
# [+] Saved pipeline to output directory
# output\model-last

# %%
nlp1 = spacy.load(r".\output\model-best") #load the best model
entity={}
doc = nlp1("John, please coordinate with the IT department to implement the necessary software updates and ensure system security.")
for ent in doc.ents:
    entity[ent.label_] = ent.text
    print(entity)
# Out:
# {'ASSIGNEE': 'John'}
# {'ASSIGNEE': 'John', 'TEXT': 'coordinate with the IT department to implement the necessary software updates and ensure system security'}
